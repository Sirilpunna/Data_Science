# %%
import matplotlib.pyplot as plt
x_values=[0,1,2,3,4,5]
y_values=[0,1,4,9,16,25]
plt.scatter(x_values,y_values,color="blue")
plt.title('Scatter Plot')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.scatter(df['deep learning'],df['machine learning'],color='red',marker="^")
plt.title('Scatter Plot')
plt.xlabel("Deep Learning")
plt.ylabel("Machine Learning")
plt.show()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.scatter(df['deep learning'],df['machine learning'],color='red',marker="^")
plt.title('Scatter Plot')
plt.xlabel("Deep Learning")
plt.ylabel("Machine Learning")
plt.grid()
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3706/3683982791.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt
values=[5,6,3,7,2]
names=["A","B","C","D","E"]
plt.bar(names,values)
plt.title("Bar Graph")
plt.xlabel("Names")
plt.ylabel("Values")
plt.show()

# %%
import matplotlib.pyplot as plt
values=[5,6,3,7,2]
names=["A","B","C","D","E"]
plt.bar(names,values,color='red')
plt.title("Bar Graph")
plt.xlabel("Names")
plt.ylabel("Values")
plt.show()

# %%
import matplotlib.pyplot as plt
values=[5,6,3,7,2]
names=["A","B","C","D","E"]
plt.barh(names,values,color='green')
plt.title("Bar Graph")
plt.xlabel("Names")
plt.ylabel("Values")
plt.show()

# %%
import matplotlib.pyplot as plt
values=[5,6,3,7,2]
names=["A","B","C","D","E"]
c1=['red','green']
c2=['b','g','y']
plt.bar(names,values,width=0.5,color=c2)
plt.show()

# %%
import matplotlib.pyplot as plt
values=[5,6,3,7,2]
names=["A","B","C","D","E"]
c1=['red','green']
c2=['b','g','y']
plt.bar(names,values,width=0.5,color=c1)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.bar(df['deep learning'],df['machine learning'],color='red')
plt.title('bar graph')
plt.xlabel("Deep Learning")
plt.ylabel("Machine Learning")
plt.show()

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv("temporal.csv")
sns.lineplot(x="data science",y="machine learning",data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.set_style("dark")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.set_style("dark")
sns.despine(left='True')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset("tips")
sns.pairplot(data,hue='day')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset("iris")
sns.pairplot(data,hue='species')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset("tips")
c_p={'Male':'lightblue','Female':'green'}
sns.pairplot(data,hue='sex',palette=c_p)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset("tips")
sns.pairplot(data[['total_bill','tip','size']])
plt.show()

# %%
import seaborn as sns
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x)
# Out:
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x,shade=True)
# Out:
# /tmp/ipykernel_1035/2328784734.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x,shade=True)
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x,shade=True)
sns.kdeplot(y)
# Out:
# /tmp/ipykernel_1035/3057685930.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x,shade=True)
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x,vertical=False)
# Out:
# /tmp/ipykernel_1035/9827722.py:5: UserWarning:
#
# The `vertical` parameter is deprecated; assigning data to `x`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x,vertical=False)
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x=x,y=y)
# Out:
# <Axes: >

# %%
import seaborn as sns
df = sns.load_dataset("iris")
sns.kdeplot(x = df["petal_length"] )
sns.kdeplot(x = df['petal_width'] , shade = True)
# Out:
# /tmp/ipykernel_1035/2447129768.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x = df['petal_width'] , shade = True)
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
import seaborn as sns
df=sns.load_dataset('iris')
sns.kdeplot(x=df['petal_length'],y=df['petal_width'])
plt.show()

# %%
import seaborn as sns
df=sns.load_dataset("tips")
sns.displot(x=df['total_bill'],kde=True,color='red',bins=30)
plt.show()

# %%
import seaborn as sns
df=sns.load_dataset("tips")
sns.displot(x=df['total_bill'],kde=True,color='red',bins=20)
plt.show()

# %%
import seaborn as sns
df=sns.load_dataset("tips")
sns.displot(x=df['total_bill'],kde=False,color='red',bins=30)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("tips")
g = sns.JointGrid(x='total_bill', y='tip', data=df)
g.plot(sns.scatterplot, sns.histplot)
plt.show()

# %%
import seaborn as sns
df=sns.load_dataset("tips")
sns.countplot(x='sex', hue='smoker', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
import seaborn as sns
df=sns.load_dataset("tips")
sns.countplot(y='sex', hue='smoker', data=df)
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
import seaborn as sns
df=sns.load_dataset("tips")
sns.boxplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
import seaborn as sns
df=sns.load_dataset("tips")
sns.boxplot(df['tip'])
# Out:
# <Axes: ylabel='tip'>

# %%
import seaborn as sns
df=sns.load_dataset("tips")
sns.boxplot(df['size'])
# Out:
# <Axes: ylabel='size'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv('/content/tips.csv')
import numpy as np

plt.boxplot(df['total_bill'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bd368973110>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7bd368973390>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7bd368972fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bd368973610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bd368973750>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv('/content/temporal.csv')
sns.boxplot(df['data science'])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv('/content/temporal.csv')
sns.boxplot(df['deep learning'])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv('/content/temporal.csv')
sns.boxplot(df['machine learning'])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df=pd.read_csv('/content/temporal.csv')
df
Q1=np.percentile(df['data science'],25,method='midpoint')
Q2=np.percentile(df['data science'],50,method='midpoint')
Q3=np.percentile(df['data science'],75)
IQR=Q3-Q1
print("the out put of IQR")
print(IQR)
# Out:
# the out put of IQR
# 20.75

# %%
import seaborn as sns
import numpy as np
df=np.random.randint(1,100,(10,10))
sns.heatmap(df)
# Out:
# <Axes: >

# %%
import seaborn as sns
import numpy as np
df=np.random.randint(1,100,(10,10))
sns.heatmap(df,vmin=30,vmax=70)
# Out:
# <Axes: >

# %%
import seaborn as sns
import numpy as np
df=np.random.randint(1,100,(10,10))
-sns.heatmap(df,vmin=30,vmax=70,annot=True)
# Out:
# <Axes: >

# %%
import seaborn as sns
import numpy as np
df=np.random.randint(1,100,(10,10))
sns.heatmap(df,cmap='tab20',annot=True)
# Out:
# <Axes: >

# %%
import seaborn as sns
data=sns.load_dataset("tips")
sns.heatmap(data[['tip']])
# Out:
# <Axes: >

# %%
import seaborn as sns
data=sns.load_dataset("iris")
sns.heatmap(data[['petal_length']])
# Out:
# <Axes: >

# %%
import seaborn as sns
data=sns.load_dataset("iris")
sns.heatmap(data[['sepal_length']])
# Out:
# <Axes: >

# %%
import seaborn as sns
data=sns.load_dataset("iris")
sns.heatmap(data[['sepal_width']])
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
data=[12,15,20,20,22,23,25,25,25,30,32,35,40]
plt.hist(data,bins=5,color='red',edgecolor='green')
plt.title("Histogram example")
plt.xlabel("Value Range")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data=sns.load_dataset("tips")
sns.histplot(data['total_bill'],bins=10,color='red',edgecolor='green')
plt.title("Histogram example")
plt.xlabel("Value Range")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data=sns.load_dataset('iris')
sns.violinplot(x='species',y='petal_length',data=data)
plt.title('Violin Plot')
plt.show()
